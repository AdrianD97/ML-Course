# %% [markdown]
# # Percentiles

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# -0.0040453274060549375

# %%
np.percentile(vals, 90)
# Out:
# 0.6423985215741637

# %%
np.percentile(vals, 20)
# Out:
# -0.4232339917576177

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters when creating the test data. What effect does it have on the percentiles?

# %%
vals2 = np.random.normal(0, 0.5, 100)

plt.hist(vals2, 50)
plt.show()

# %%
np.percentile(vals2, 75)
# Out:
# 0.367522742895718
